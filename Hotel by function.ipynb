# %%
sum=0
def welcome():
    print("           Yash Da Dhaba")
    print("               ----------------------------")
    print("Select your option:")
    print("A.for Veg")
    print("B.for Non veg")    
    print("C.for Snacks")    
    menu()
def menu(): 
    option = input("Enter your option:")
    if(option=="A"):
        print("              -------------VEG-------------")
        veg()
        add()
    elif(option=="B"):
        print("              -----------NON VEG-----------")
        non_veg()
        add()
    elif(option=="C"):
        print("              ----------ICE CREAM-----------")
        ice_cream()
        add()
    else:
        print("Please enter the correct option!")
        option = (input("Again enter your option:"))
        menu(option)

def veg():
    print("1A.Veg Biryani     200Rs")
    print("2A.Veg  Noodles    100Rs")
    print("3A.Fried Rice      150Rs")
    print("4A.Veg Manchurian  150Rs")
    print("5A.Samosa          50Rs")
    dish_name = input("Enter your dish:")
    quantity = int(input("Quantity:"))
    Bill(dish_name,quantity)
def non_veg():
    print("1B.Mutton Biryani           300Rs")
    print("2B.Chicken Tikka Kabab      250Rs")
    print("3B.Tandoori Chicken Pakoda  250Rs")
    print("4B.Chicken Leg Piece        200Rs")
    print("5B.Chicken Biryani          200Rs")
    dish_name = input("Enter your dish:")
    quantity = int(input("Quantity:"))
    Bill(dish_name,quantity)
def ice_cream():
    print("1C.Chocclate flavour       150Rs")
    print("2C.Badam pista flavour     150Rs")
    print("3C.Butter scott flavour    150Rs")
    print("4C.Vanila flavour          150Rs")
    print("5C.Strawberry              150Rs")
    dish_name = input("Enter your dish:")
    quantity = int(input("Quantity:"))
    Bill(dish_name,quantity)
    
def Bill(dish_name,quantity):
    global sum
    if(dish_name=="1A"):        
        bill=quantity*200
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="2A"):
        bill=quantity*100
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="3A"):
        bill=quantity*150
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name==""):
        bill=quantity*150
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="5A"):
        bill=quantity*50
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="1B"):
        bill=quantity*300
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="2B"):
        bill=quantity*250
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="3B"):
        bill=quantity*250
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="4B"):
        bill=quantity*200
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="5B"):
        bill=quantity*200
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="1C"):
        bill=quantity*150
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="2C"):
        bill=quantity*150
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="3C"):
        bill=quantity*150
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="4C"):
        bill=quantity*150
        sum=sum+bill
        print("Your amount is",bill)
    elif(dish_name=="5C"):
        bill=quantity*150
        sum=sum+bill
        print("Your amount is",bill)

def add():
    ans = input("Enter your second order?")
    if(ans=="yes"):
        print("Select your option:")
        print("A.for Veg")
        print("B.for Non veg")    
        print("C.for Icecream")
        
        menu()
    else:
        print("             -------------EXIT-------------")
    
def dis():
    day=int(input("Enter todays day:"))
    if(day== 1)
    
    print("Todays discount is 15%")
    discount=sum*15/100
    total_bill=sum-discount
    print("Your total bill amount is",total_bill)
    elif(day==2)
    print("Todays discount is 13%")
    discount=sum*13/100
    total_bill=sum-discount
    print("Your total bill amount is",total_bill)
    elif(day==3)
    print("Todays discount is 20%")
    discount=sum*20/100
    total_bill=sum-discount
    print("Your total bill amount is",total_bill)
    elif(day==4)
    print("Todays discount is 22%")
    discount=sum*22/100
    total_bill=sum-discount
    print("Your total bill amount is",total_bill)
    elif(day==5)
    print("Todays discount is 25%")
    discount=sum*25/100
    total_bill=sum-discount
    print("Your total bill amount is",total_bill)
    elif(day==6)
    print("Todays discount is 35%")
    discount=sum*35/100
    total_bill=sum-discount
    print("Your total bill amount is",total_bill)
    elif(day==7)
    print("Todays discount is 40%")
    discount=sum*40/100
    total_bill=sum-discount
    print("Your total bill amount is",total_bill)
    

    




welcome()
# Out:
#   Input In [1]
#     if(day==1)
#               ^
# SyntaxError: invalid syntax
